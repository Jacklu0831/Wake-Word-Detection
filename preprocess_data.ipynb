# %% [markdown]
# # Wake Word Detection (process raw data)
#
# Wake word detection is about letting a virtual voice assistant recognize a word for waking up or to execute a certain action, like “Hey Siri” or “Hey Alexa”. The dataset and some methods for this project came from CS230 at Stanford by Andrew Ng.
#
# ### Requirements
# - numpy
# - h5py
# - pydub
# - matplotlib
# - scipy
# - keras
#
# ### Running this notebook needs files (can all be found in the repo):
# The positive, negative, and background datasets (I recommend making your own dataset for best performance)
# - my_raw_input.zip

# %%
# !pip install pydub

from scipy.io import wavfile
from pydub import AudioSegment
import matplotlib.pyplot as plt
import os
# Out:
# Collecting pydub
#   Downloading https://files.pythonhosted.org/packages/79/db/eaf620b73a1eec3c8c6f8f5b0b236a50f9da88ad57802154b7ba7664d0b8/pydub-0.23.1-py2.py3-none-any.whl
# Installing collected packages: pydub
# Successfully installed pydub-0.23.1

# %% [markdown]
# ## Process Data

# %%
# !unzip my_raw_input.zip # local zip included in the repo
root = "./my_raw_input/"

import IPython
import numpy as np
import random
import sys
import io
import glob
# %matplotlib inline
# Out:
# Archive:  my_raw_input.zip
#    creating: my_raw_input/
#    creating: my_raw_input/background/
#   inflating: my_raw_input/background/night_rain.wav
#    creating: __MACOSX/
#    creating: __MACOSX/my_raw_input/
#    creating: __MACOSX/my_raw_input/background/
#   inflating: __MACOSX/my_raw_input/background/._night_rain.wav
#   inflating: my_raw_input/background/background.wav
#   inflating: __MACOSX/my_raw_input/background/._background.wav
#   inflating: my_raw_input/background/air.wav
#   inflating: __MACOSX/my_raw_input/background/._air.wav
#   inflating: __MACOSX/my_raw_input/._background
#    creating: my_raw_input/positive/
#   inflating: my_raw_input/positive/p8.wav
#    creating: __MACOSX/my_raw_input/positive/
#   inflating: __MACOSX/my_raw_input/positive/._p8.wav
#   inflating: my_raw_input/positive/p9.wav
#   inflating: __MACOSX/my_raw_input/positive/._p9.wav
#   inflating: my_raw_input/positive/p10.wav
#   inflating: __MACOSX/my_raw_input/positive/._p10.wav
#   inflating: my_raw_input/positive/p11.wav
#   inflating: __MACOSX/my_raw_input/positive/._p11.wav
#   inflating: my_raw_input/positive/p13.wav
#   inflating: __MACOSX/my_raw_input/positive/._p13.wav
#   inflating: my_raw_input/positive/p12.wav
#   inflating: __MACOSX/my_raw_input/positive/._p12.wav
#   inflating: my_raw_input/positive/p15.wav
#   inflating: __MACOSX/my_raw_input/positive/._p15.wav
#   inflating: my_raw_input/positive/p14.wav
#   inflating: __MACOSX/my_raw_input/positive/._p14.wav
#   inflating: my_raw_input/positive/p1.wav
#   inflating: __MACOSX/my_raw_input/positive/._p1.wav
#   inflating: my_raw_input/positive/p2.wav
#   inflating: __MACOSX/my_raw_input/positive/._p2.wav
#   inflating: my_raw_input/positive/p3.wav
#   inflating: __MACOSX/my_raw_input/positive/._p3.wav
#   inflating: my_raw_input/positive/p7.wav
#   inflating: __MACOSX/my_raw_input/positive/._p7.wav
#   inflating: my_raw_input/positive/p6.wav
#   inflating: __MACOSX/my_raw_input/positive/._p6.wav
#   inflating: my_raw_input/positive/p4.wav
#   inflating: __MACOSX/my_raw_input/positive/._p4.wav
#   inflating: my_raw_input/positive/p5.wav
#   inflating: __MACOSX/my_raw_input/positive/._p5.wav
#    creating: my_raw_input/negative/
#   inflating: my_raw_input/negative/because.wav
#    creating: __MACOSX/my_raw_input/negative/
#   inflating: __MACOSX/my_raw_input/negative/._because.wav
#   inflating: my_raw_input/negative/have.wav
#   inflating: __MACOSX/my_raw_input/negative/._have.wav
#   inflating: my_raw_input/negative/important.wav
#   inflating: __MACOSX/my_raw_input/negative/._important.wav
#   inflating: my_raw_input/negative/life.wav
#   inflating: __MACOSX/my_raw_input/negative/._life.wav
#   inflating: my_raw_input/negative/in.wav
#   inflating: __MACOSX/my_raw_input/negative/._in.wav
#   inflating: my_raw_input/negative/all.wav
#   inflating: __MACOSX/my_raw_input/negative/._all.wav
#   inflating: my_raw_input/negative/that.wav
#   inflating: __MACOSX/my_raw_input/negative/._that.wav
#   inflating: my_raw_input/negative/him.wav
#   inflating: __MACOSX/my_raw_input/negative/._him.wav
#   inflating: my_raw_input/negative/hey.wav
#   inflating: __MACOSX/my_raw_input/negative/._hey.wav
#   inflating: my_raw_input/negative/would.wav
#   inflating: __MACOSX/my_raw_input/negative/._would.wav
#   inflating: my_raw_input/negative/with.wav
#   inflating: __MACOSX/my_raw_input/negative/._with.wav
#   inflating: my_raw_input/negative/public.wav
#   inflating: __MACOSX/my_raw_input/negative/._public.wav
#   inflating: my_raw_input/negative/person.wav
#   inflating: __MACOSX/my_raw_input/negative/._person.wav
#   inflating: my_raw_input/negative/machine.wav
#   inflating: __MACOSX/my_raw_input/negative/._machine.wav
#   inflating: my_raw_input/negative/learning.wav
#   inflating: __MACOSX/my_raw_input/negative/._learning.wav
#   inflating: my_raw_input/negative/shit.wav
#   inflating: __MACOSX/my_raw_input/negative/._shit.wav
#   inflating: my_raw_input/negative/work.wav
#   inflating: __MACOSX/my_raw_input/negative/._work.wav
#   inflating: my_raw_input/negative/world.wav
#   inflating: __MACOSX/my_raw_input/negative/._world.wav
#   inflating: my_raw_input/negative/today.wav
#   inflating: __MACOSX/my_raw_input/negative/._today.wav
#   inflating: my_raw_input/negative/jesus.wav
#   inflating: __MACOSX/my_raw_input/negative/._jesus.wav
#   inflating: my_raw_input/negative/plane.wav
#   inflating: __MACOSX/my_raw_input/negative/._plane.wav
#   inflating: my_raw_input/negative/fuck.wav
#   inflating: __MACOSX/my_raw_input/negative/._fuck.wav
#   inflating: my_raw_input/negative/same.wav
#   inflating: __MACOSX/my_raw_input/negative/._same.wav
#   inflating: my_raw_input/negative/time.wav
#   inflating: __MACOSX/my_raw_input/negative/._time.wav
#   inflating: my_raw_input/negative/about.wav
#   inflating: __MACOSX/my_raw_input/negative/._about.wav
#   inflating: my_raw_input/negative/programming.wav
#   inflating: __MACOSX/my_raw_input/negative/._programming.wav
#   inflating: my_raw_input/negative/of.wav
#   inflating: __MACOSX/my_raw_input/negative/._of.wav
#   inflating: my_raw_input/negative/which.wav
#   inflating: __MACOSX/my_raw_input/negative/._which.wav
#   inflating: my_raw_input/negative/a.wav
#   inflating: __MACOSX/my_raw_input/negative/._a.wav
#   inflating: my_raw_input/negative/problem.wav
#   inflating: __MACOSX/my_raw_input/negative/._problem.wav
#   inflating: my_raw_input/negative/government.wav
#   inflating: __MACOSX/my_raw_input/negative/._government.wav
#   inflating: my_raw_input/negative/to.wav
#   inflating: __MACOSX/my_raw_input/negative/._to.wav
#   inflating: my_raw_input/negative/damnit.wav
#   inflating: __MACOSX/my_raw_input/negative/._damnit.wav
#   inflating: my_raw_input/negative/killyourself.wav
#   inflating: __MACOSX/my_raw_input/negative/._killyourself.wav
#   inflating: my_raw_input/negative/most.wav
#   inflating: __MACOSX/my_raw_input/negative/._most.wav
#   inflating: my_raw_input/negative/their.wav
#   inflating: __MACOSX/my_raw_input/negative/._their.wav
#   inflating: my_raw_input/negative/great.wav
#   inflating: __MACOSX/my_raw_input/negative/._great.wav
#   inflating: my_raw_input/negative/people.wav
#   inflating: __MACOSX/my_raw_input/negative/._people.wav
#   inflating: my_raw_input/negative/be.wav
#   inflating: __MACOSX/my_raw_input/negative/._be.wav
#   inflating: my_raw_input/negative/christ.wav
#   inflating: __MACOSX/my_raw_input/negative/._christ.wav
#   inflating: my_raw_input/negative/other.wav
#   inflating: __MACOSX/my_raw_input/negative/._other.wav
#   inflating: my_raw_input/negative/company.wav
#   inflating: __MACOSX/my_raw_input/negative/._company.wav
#   inflating: my_raw_input/negative/when.wav
#   inflating: __MACOSX/my_raw_input/negative/._when.wav
#   inflating: my_raw_input/negative/man.wav
#   inflating: __MACOSX/my_raw_input/negative/._man.wav
#   inflating: my_raw_input/negative/his.wav
#   inflating: __MACOSX/my_raw_input/negative/._his.wav
#   inflating: my_raw_input/negative/society.wav
#   inflating: __MACOSX/my_raw_input/negative/._society.wav
#   inflating: my_raw_input/negative/even.wav
#   inflating: __MACOSX/my_raw_input/negative/._even.wav
#   inflating: my_raw_input/negative/eat.wav
#   inflating: __MACOSX/my_raw_input/negative/._eat.wav
#   inflating: my_raw_input/negative/her.wav
#   inflating: __MACOSX/my_raw_input/negative/._her.wav

# %% [markdown]
# #### Showcase data
#
# The positive (containing "activate"), negative, and background audio files are separated, allowing us to synthesize more combination of data.

# %%
IPython.display.Audio(os.path.join(root, "positive/p1.wav"))
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
IPython.display.Audio(os.path.join(root, "negative/to.wav"))
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
IPython.display.Audio(os.path.join(root, "background/night_rain.wav"))
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# get the audio hz
rate, audio_data = wavfile.read(os.path.join(root, "background/night_rain.wav"))
print(f"Sample rate: {rate}")
print(f"Time steps: {len(audio_data)}")
# Out:
# Sample rate: 44100
# Time steps: 441000

# %% [markdown]
# #### Convert audio to spectrogram

# %%
def graph_spectrogram(wav_file):
    """
    Plot and calculate spectrogram for audio (.wav)
    """
    rate, audio_data = wavfile.read(wav_file) # load wavfile
    n_fft = 200 # window length (length of fast fourier transform)
    sf = 8000 # number of samples per time (sample frequency)
    n_overlap = 120 # overlap length of windows
    n_channels = audio_data.ndim # number of dimensions
    if n_channels == 1:
        pxx, freqs, bins, im = plt.specgram(audio_data, n_fft, sf, noverlap = n_overlap)
    elif n_channels == 2: # multi-channel audio
        pxx, freqs, bins, im = plt.specgram(audio_data[:,0], n_fft, sf, noverlap = n_overlap)
    return pxx

# %%
specgram = graph_spectrogram(os.path.join(root, "background/night_rain.wav"))

print(f"Number of frequencies of spectrogram: {specgram.shape[0]}")
print(f"Number of timesteps of spectrogram: {specgram.shape[1]}")
# Out:
# Number of frequencies of spectrogram: 101
# Number of timesteps of spectrogram: 5511

# %% [markdown]
# #### Define parameters for 10 second audio

# %%
T_x = 5511 # input time steps
T_y = 1375 # output time steps of model
n_freq = 101 # number of discrete audio frequencies

# %% [markdown]
# #### Get data with pydub

# %%
def load_raw_audio(root):
    """
    Load raw audio file for audio synthesis
    """
    positives = []
    negatives = []
    backgrounds = []
    
    for filename in os.listdir(os.path.join(root, "positive")):
        if filename.endswith("wav"):
            path = os.path.join(root, "positive", filename)
            positives.append(AudioSegment.from_wav(path))
            
    for filename in os.listdir(os.path.join(root, "negative")):
        if filename.endswith("wav"):
            path = os.path.join(root, "negative", filename)
            negatives.append(AudioSegment.from_wav(path))
            
    for filename in os.listdir(os.path.join(root, "background")):
        if filename.endswith("wav"):
            path = os.path.join(root, "background", filename)
            backgrounds.append(AudioSegment.from_wav(path))
    
    return positives, negatives, backgrounds

# %%
positives, negatives, backgrounds = load_raw_audio(root)
print("Average positive length: ", sum([len(x)/1000 for x in positives])/len(positives), "s")
print("Average negative length: ", sum([len(x)/1000 for x in negatives])/len(negatives), "s")
print("Background length: ", len(backgrounds[0])/1000, "s")
# as shown in the input, "activate" is quite a long word
# Out:
# Average positive length:  0.6066666666666666 s
# Average negative length:  0.3551020408163266 s
# Background length:  10.0 s

# %% [markdown]
# #### Perform audio synthesis
#
# This is a relatively difficult part of the project involving randomly overlaying positive/negative audios on backgrounds without overlap and labelling the data at the same time.

# %%
def get_random_segment(duration, length=1e4):
    """
    Gets a random time segment in audio clip (default length = 10s * 1000ms/s)
    """
    start = np.random.randint(low=0, high=length-duration)
    end = start + duration - 1 # a careful "-1" for edge case
    return (start, end)

# %%
def is_overlapping(new_seg, segs):
    """
    Checks if new segment overlaps with existing ones
    """
    overlap = False
    start, end = new_seg
    for ex_start, ex_end in segs:
        if start <= ex_end and end >= ex_start:
            overlap = True
    return overlap

# %%
def insert_clip(background, clip, segs):
    """
    Insert new audio clip in background while avoiding overlaps
    """
    duration = len(clip)
    new_seg = get_random_segment(duration)
    while is_overlapping(new_seg, segs): # poke around until finding space
        new_seg = get_random_segment(duration)
    
    segs.append(new_seg) # update existing segs
    background = background.overlay(clip, position=new_seg[0]) # overlay
    return background, new_seg

# %%
def update_label(y, seg_end, length=1e4):
    """
    Update label y with 1s at 50 output steps after each positive segment 
    y is a vector with shape (1, T_y)
    """
    seg_end_output = int(seg_end*(T_y/length)) # convert I/O time scale
    for end in range(seg_end_output+1, seg_end_output+51):
        if end < T_y: # ensure stop at end of audio
            y[0, end] = 1.0
    return y

# %%
def standardize_volume(sound, target):
    """
    Standardize volume of audio clip (decibel relative to full scale)
    """
    delta = target - sound.dBFS # difference between dB FS
    return sound.apply_gain(delta)

# %%
def create_train_data(background, positives, negatives):
    background -= 20 # arbitrarily dimming the background noise
    y = np.zeros((1, T_y))
    segs = []
    
    # get positives
    n_p = np.random.randint(0, 5)
    n_p_indices = np.random.randint(len(positives), size=n_p)
    n_positives = [positives[idx] for idx in n_p_indices]
    
    # insert and update label
    for positive in n_positives:
        background, new_seg = insert_clip(background, positive, segs)
        start, end = new_seg
        y = update_label(y, end)
    
    # get negatives
    n_n = np.random.randint(0, 3)
    n_n_indices = np.random.randint(len(negatives), size=n_n)
    n_negatives = [negatives[idx] for idx in n_n_indices]
    
    # insert and update label
    for negative in n_negatives:
        background, _ = insert_clip(background, negative, segs)
    
    # standardize volume
    background = standardize_volume(background, -20.0)
    
    # save file
    _ = background.export("test.wav", format="wav")
    
    # spectrogram
    x = graph_spectrogram("test.wav")
    
    return x, y

# %% [markdown]
# #### Test audio synthesis functions
#
# Rerun below cells to test the code.

# %%
x, y = create_train_data(backgrounds[0], positives, negatives)

# %%
IPython.display.Audio("test.wav")
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
plt.plot(y[0])

# %% [markdown]
# ### Generate Data

# %%
def create_train_data(background, positives, negatives):
    background -= 20 # arbitrarily dimming the background noise
    y = np.zeros((1, T_y))
    segs = []
    
    # get positives
    n_p = np.random.randint(0, 5)
    n_p_indices = np.random.randint(len(positives), size=n_p)
    n_positives = [positives[idx] for idx in n_p_indices]
    
    # insert and update label
    for positive in n_positives:
        background, new_seg = insert_clip(background, positive, segs)
        start, end = new_seg
        y = update_label(y, end)
    
    # get negatives
    n_n = np.random.randint(0, 3)
    n_n_indices = np.random.randint(len(negatives), size=n_n)
    n_negatives = [negatives[idx] for idx in n_n_indices]
    
    # insert and update label
    for negative in n_negatives:
        background, _ = insert_clip(background, negative, segs)
    
    # standardize volume
    background = standardize_volume(background, -20.0)
    
    # save file
    _ = background.export("out.wav", format="wav")
    
    # spectrogram
    x = graph_spectrogram("out.wav")
    
#     swap axes
#     x = x.swapaxes(0, 1)
#     y = y.swapaxes(0, 1)

    return x, y

# %%
x_train = []
x_test = []
y_train = []
y_test = []

for i in range(len(backgrounds)):   
    print(f"\nbackground #{i+1}")
    for j in range(120):
        x, y = create_train_data(backgrounds[i], positives, negatives)
        x_train.append(x)
        y_train.append(y)
        
print("\nDONE TRAINING DATASET")
        
for i in range(len(backgrounds)):   
    print(f"\nbackground #{i+1}")
    for j in range(30):
        x, y = create_train_data(backgrounds[i], positives, negatives)
        x_test.append(x)
        y_test.append(y)

print("\nDONE TESTING DATASET")
# Out:
# background #1
#
# background #2
#
# background #3
#
# DONE TRAINING DATASET
#
# background #1
#
# background #2
#
# background #3
#
# DONE TESTING DATASET

# %%
for i in range(len(x_train)):
    x_train[i] = x_train[i].swapaxes(0, 1)
    y_train[i] = y_train[i].swapaxes(0, 1)

for i in range(len(x_test)):
    x_test[i] = x_test[i].swapaxes(0, 1)
    y_test[i] = y_test[i].swapaxes(0, 1)

print("x_train shape: ", np.shape(x_train))
print("y_train shape: ", np.shape(y_train))
print("x_test shape: ", np.shape(x_test))
print("y_test shape: ", np.shape(y_test))
# Out:
# x_train shape:  (360, 5511, 101)
# y_train shape:  (360, 1375, 1)
# x_test shape:  (90, 5511, 101)
# y_test shape:  (90, 1375, 1)

# %% [markdown]
# ### Save to .npy

# %%
np.save("X.npy", x_train)
np.save("Y.npy", y_train)
np.save("X_dev.npy", x_test)
np.save("Y_dev.npy", y_test)
